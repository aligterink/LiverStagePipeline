# %%
from utils import setup, data_utils, cell_viewer
import imageio.v3
import numpy as np

# %%
tif_folder = '/mnt/DATA1/anton/data/hepatocyte_annotated_dataset/images/highres'
seg_dirs = [
    '/mnt/DATA1/anton/data/hepatocyte_annotated_dataset/annotation', # hepatocyte annotation
    '/mnt/DATA1/anton/data/hepatocyte_annotated_dataset/hepatocyte_watershed'
]

cell_viewer.show_folder(tif_dir=tif_folder, seg_dirs=seg_dirs, eval=False, num_rows=1, num_images=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/anton/Documents/code/LiverStagePipeline/vis_cells.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell://ssh-remote%2B10.10.3.247/home/anton/Documents/code/LiverStagePipeline/vis_cells.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tif_folder = '/mnt/DATA1/anton/data/hepatocyte_annotated_dataset/images'
#       <a href='vscode-notebook-cell://ssh-remote%2B10.10.3.247/home/anton/Documents/code/LiverStagePipeline/vis_cells.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> seg_dirs = [
#       <a href='vscode-notebook-cell://ssh-remote%2B10.10.3.247/home/anton/Documents/code/LiverStagePipeline/vis_cells.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     '/mnt/DATA1/anton/data/hepatocyte_annotated_dataset/annotation', # hepatocyte annotation
# ...

# %%
for x in data_utils.get_paths('/mnt/DATA1/anton/data/hepatocyte_annotated_dataset/hepatocyte_watershed'):
    m = imageio.imread(x)
    print(len(np.unique(m)))
# Out:
# /tmp/ipykernel_1094406/2677706503.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   m = imageio.imread(x)
# 450
# 468
# 363
# 398
# 460
# 497
# 511
# 484
# 459
# 426
# 430
# 446
# 421
# 438
# 474
# 477
# 476
# 390
# 371
# 457
# 438
# 473
# 464
# 486
# 408
# 546
# 581
# 597
# 602
# 572
# 562
# 511
# 547
# 512
# 553
# 585
# 600
# 579
# 604
# 587
# 566
# 618
# 599
# 570
# 547
# 581
# 572
# 592
# 551
# 596
# 576
# 572
# 592
# 596
# 560
# 578
# 578
# 560
# 552
# 572
# 595
# 602
# 555
# 536
# 574
# 545
# 588
# 590
# 553
# 581
# 583
# 563
# 616
# 576
# 576
# 571
# 551
# 537
# 526
# 552
# 540
# 488
# 542
# 553
# 559
# 543
# 556
# 544
# 527
# 541
# 533
# 527
# 522
# 527
# 562
# 597
# 619
# 578
# 567
# 584
# 610
# 590
# 590
# 591
# 569
# 540
# 553
# 566
# 546
# 554
# 521
# 555
# 609
# ...
